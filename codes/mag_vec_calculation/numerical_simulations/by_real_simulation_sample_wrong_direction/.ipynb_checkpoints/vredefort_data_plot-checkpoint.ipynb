# %% [markdown]
# # Vredefort sample data set from PUC-rio

# %% [markdown]
# #### Import libraries

# %%
# %matplotlib inline
from IPython.display import Markdown as md
from IPython.display import display as dp
import string as st
import sys
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
import datetime
import pandas as pd

from fatiando.utils import ang2vec, vec2ang,fromimage
from fatiando.mesher import Sphere, Prism, PolygonalPrism
from fatiando.gravmag import sphere, prism, polyprism
from fatiando.gridder import regular
# Out:
# /home/andrelreis/anaconda2/lib/python2.7/site-packages/fatiando/vis/mpl.py:76: UserWarning: This module will be removed in v0.6. We recommend the use of matplotlib.pyplot module directly. Some of the fatiando specific functions will remain.
#   "specific functions will remain.")

# %%
notebook_name = 'vredefort_data_plot.ipynb'

# %% [markdown]
# ### Plot style

# %%
plt.style.use('ggplot')

# %% [markdown]
# #### Importing auxiliary functions

# %%
dir_modules = '../../'
sys.path.append(dir_modules)

# %%
import my_package as fc

# %% [markdown]
# ### Loading regular grid

# %%
with open('data/regular_grid.pickle') as f:
        grid = pickle.load(f)

# %% [markdown]
# ## Open a dictionary

# %%
data_set = dict()

# %% [markdown]
# #### List of saved files

# %%
saved_files = []

# %% [markdown]
# ## Loading from a .txt file

# %%
filename = 'real_data/MAPx280620191934.txt'

# %%
data = pd.read_csv(filename,delim_whitespace=True)

# %%
data
# Out:
#      1.152046E-4  1.850136E-4  1.716620E-5  8.392400E-6  1.342782E-4  \
# 0       0.000149     0.000120     0.000235     0.000197     0.000173
# 1       0.000163     0.000034     0.000174     0.000171     0.000073
# 2       0.000202     0.000163     0.000130     0.000131     0.000304
# 3      -0.000088     0.000012    -0.000094    -0.000059    -0.000251
# 4      -0.000064    -0.000018    -0.000129    -0.000199    -0.000130
# 5      -0.000143    -0.000211    -0.000121    -0.000071    -0.000117
# 6      -0.000206    -0.000319    -0.000275    -0.000301    -0.000292
# 7      -0.000731    -0.000649    -0.000548    -0.000655    -0.000709
# 8      -0.000230    -0.000179    -0.000195    -0.000075    -0.000097
# 9      -0.000068    -0.000141    -0.000153    -0.000175    -0.000029
# 10     -0.000165    -0.000017    -0.000174    -0.000115    -0.000136
# 11     -0.000597    -0.000487    -0.000233    -0.000218    -0.000073
# 12     -0.000160    -0.000104    -0.000155    -0.000042    -0.000083
# 13     -0.000213    -0.000129    -0.000296    -0.000235    -0.000259
# 14     -0.000096    -0.000175    -0.000173    -0.000093    -0.000153
# 15     -0.000128    -0.000206    -0.000056    -0.000143    -0.000105
# 16     -0.000165    -0.000185    -0.000278    -0.000354    -0.000318
# 17     -0.000083    -0.000085    -0.000125    -0.000235    -0.000234
# 18     -0.000067    -0.000129    -0.000127    -0.000171    -0.000169
# 19     -0.000073    -0.000039    -0.000135    -0.000262    -0.000183
# 20      0.000058    -0.000088    -0.000241    -0.000202    -0.000107
# 21      0.000145    -0.000147    -0.000175    -0.000055    -0.000227
# 22     -0.000045    -0.000264    -0.000273    -0.000361    -0.000240
# 23      0.000028    -0.000134    -0.000222    -0.000340    -0.000309
# 24      0.000012    -0.000256    -0.000205    -0.000229    -0.000240
# 25      0.000120    -0.000041    -0.000047    -0.000212    -0.000133
# 26      0.000251    -0.000151    -0.000201    -0.000303    -0.000322
# 27     -0.000216    -0.000507    -0.000511    -0.000545    -0.000593
# 28     -0.000177    -0.000441    -0.000482    -0.000406    -0.000418
# 29      0.000068    -0.000058    -0.000085    -0.000140    -0.000201
# ..           ...          ...          ...          ...          ...
# 168     0.000389     0.000459     0.000409     0.000386     0.000313
# 169     0.000374     0.000310     0.000323     0.000331     0.000273
# (242, 198)

# %% [markdown]
# ### Parameters of acquisition

# %%
data_set['L_top'] = -1135.
data_set['L_bottom'] = 1135.

# %%
data_set['shape'] = data_set['obs'].shape

# %%
data_set['Nx'], data_set['Ny'] = 242,198

# %%
data_set['area'] = [-36084.,0.,0.,29636.]

# %%
data_set['z_obs'] = -138. + data_set['L_top']

# %%
xp,yp,zp = regular(data_set['area'],data_set['shape'],data_set['z_obs'])

# %%
Y = yp.reshape(data_set['shape'])
X = xp.reshape(data_set['shape'])

# %% [markdown]
# ### Visualization of data set of Vredefort sample

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(8,8), tight_layout=True)

plt.xlabel('y (mm)', fontsize = title_font)
plt.ylabel('x (mm)', fontsize = title_font)
plt.title('Bz (observed data)', fontsize=title_font)
plt.contourf(1e-3*Y.reshape(data_set['shape']),1e-3*X.reshape(data_set['shape']),
             data_set['obs'],40,cmap='viridis',vmin=-4.,vmax=4.)
plt.tick_params(axis='both', which='major', labelsize=bottom_font)
cb = plt.colorbar(pad=0.01, aspect=40, shrink=1.0)
cb.set_label('mT',size=bottom_font)
cb.ax.tick_params(labelsize=bottom_font)

file_name = 'figs/vred_data_full_bz'
plt.savefig(file_name+'.png',dpi=400)
saved_files.append(file_name+'.png')


plt.show()
# Out:
# /home/andrelreis/anaconda2/lib/python2.7/site-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ## Decimating the data

# %%
filtered_data = data_set['obs'].iloc[range(0,data_set['obs'].shape[0],2),
                                     range(0,data_set['obs'].shape[1],2)]

# %%
data_set['obs_decimated'] = filtered_data.values

# %%
data_set['shape_decimated'] = data_set['obs_decimated'].shape

# %%
print data_set['shape_decimated']
# Out:
# (121, 99)

# %%
xd,yd,zd = regular(data_set['area'],data_set['shape_decimated'],data_set['z_obs'])

# %%
Yd = yd.reshape(data_set['shape_decimated'])
Xd = xd.reshape(data_set['shape_decimated'])

# %% [markdown]
# ### Visualization of decimated data for vredefort

# %%
title_font = 20
bottom_font = 16
saturation_factor = 1.
plt.close('all')
plt.figure(figsize=(8,8), tight_layout=True)

plt.xlabel('y (mm)', fontsize = title_font)
plt.ylabel('x (mm)', fontsize = title_font)
plt.title('Bz (observed)', fontsize=title_font)
plt.contourf(1e-3*Yd.reshape(data_set['shape_decimated']),
             1e-3*Xd.reshape(data_set['shape_decimated']),
             data_set['obs_decimated'],40,cmap='viridis',vmin=-4.,vmax=4.)
plt.tick_params(axis='both', which='major', labelsize=bottom_font)
cb = plt.colorbar(pad=0.01, aspect=40, shrink=1.0)
cb.set_label('mT',size=bottom_font)
cb.ax.tick_params(labelsize=bottom_font)


file_name = 'figs/vred_data_decimated_bz'
plt.savefig(file_name+'.png',dpi=200)
saved_files.append(file_name+'.png')


plt.show()

# %% [markdown]
# #### Generating .pickle file

# %%
now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
data_set['metadata'] = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)

# %%
file_name = 'data/data_set.pickle'
with open(file_name, 'w') as f:
    pickle.dump(data_set, f)
    
saved_files.append(file_name)

# %% [markdown]
# #### Saved files

# %%
with open('reports/report_%s.md' % notebook_name[:st.index(notebook_name, '.')], 'w') as q:
    q.write('# Saved files \n')
    now = datetime.datetime.utcnow().strftime('%d %B %Y %H:%M:%S UTC')
    header = 'Generated by {name} on {date}'.format(date=now, name=notebook_name)
    q.write('\n\n'+header+'\n\n')
    for i, sf in enumerate(saved_files):
        print '%d  %s' % (i+1,sf)
        q.write('*  `%s` \n' % (sf))
# Out:
# 1  figs/vred_data_full_bz.png
# 2  figs/vred_data_decimated_bz.png
# 3  data/data_set.pickle
